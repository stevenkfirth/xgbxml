# %% [markdown]
# # query_examples

# %% [markdown]
# ## Areas by surfaceType

# %%
from lxml import etree
import xgbxml

parser = xgbxml.get_parser('0.37')   

tree = etree.parse('gbXMLStandard.xml', parser)  # file available on GitHub here: https://github.com/GreenBuildingXML/Sample_gbXML_Files
gbxml = tree.getroot()

result = {}
for surface in gbxml.Campus.Surfaces:
    
    surface_type = surface.surfaceType
    
    try:  
        surface_plus_openings_area = surface.PlanarGeometry.get_area()  # this raises an error in a few cases as the polygon in the 'gbXMLStandard.xml' file has three adjacent vertices on a line.
    except ValueError:
        print(f'Error raised for get_area() of Surface {surface.id}')
        continue
    
    x = result.setdefault(surface_type,0)
    result[surface_type] = x + surface_plus_openings_area
    
print(result)
# prints "{'ExteriorWall': 38663.957965668895, 
#          'Shade': 3602.1242386749996, 
#          'InteriorWall': 59075.35491038435, 
#          'InteriorFloor': 71901.632959902, 
#          'Ceiling': 2041.1025198133002, 
#          'Roof': 20895.388879540173, 
#          'SlabOnGrade': 19542.64927603096}"
# Out:
# Error raised for get_area() of Surface aim13507
# Error raised for get_area() of Surface aim63130
# Error raised for get_area() of Surface aim63304
# Error raised for get_area() of Surface aim63597
# Error raised for get_area() of Surface aim64087
# Error raised for get_area() of Surface aim64196
# Error raised for get_area() of Surface aim64265
# Error raised for get_area() of Surface aim64468
# Error raised for get_area() of Surface aim66653
# Error raised for get_area() of Surface aim66697
# Error raised for get_area() of Surface aim66835
# Error raised for get_area() of Surface aim67086
# Error raised for get_area() of Surface aim67132
# Error raised for get_area() of Surface aim67538
# Error raised for get_area() of Surface aim68038
# Error raised for get_area() of Surface aim68130
# Error raised for get_area() of Surface aim72743
# Error raised for get_area() of Surface aim82996
# Error raised for get_area() of Surface aim87784
# Error raised for get_area() of Surface aim92195
# {'ExteriorWall': 38663.957965668895, 'Shade': 3602.1242386749996, 'InteriorWall': 59075.35491038435, 'InteriorFloor': 71901.632959902, 'Ceiling': 2041.1025198133002, 'Roof': 20895.388879540173, 'SlabOnGrade': 19542.64927603096}

# %% [markdown]
# ## Areas and window-to-wall ratio by orientation

# %%
from lxml import etree
import xgbxml

parser=xgbxml.get_parser('0.37')   

tree=etree.parse('gbXMLStandard.xml', parser)  # file available on GitHub here: https://github.com/GreenBuildingXML/Sample_gbXML_Files
gbxml=tree.getroot()

result={}
for surface in gbxml.Campus.Surfaces:
    
    cad_model_azimuth = gbxml.Campus.Location.CADModelAzimuth.value
    surface_azimuth = surface.RectangularGeometry.Azimuth.value
    orientation = cad_model_azimuth + surface_azimuth
    
    try:
        total_area=surface.PlanarGeometry.get_area()  # this raises an error in a few cases as the polygon in the 'gbXMLStandard.xml' file has three adjacent vertices on a line.
        surface_area=surface.get_area()  # this raises an error in a few cases as the polygon in the 'gbXMLStandard.xml' file has three adjacent vertices on a line.
    except ValueError:
        print(f'Error raised for get_area() of Surface {surface.id}')
        continue
        
    opening_area = total_area - surface_area   
    
    x=result.setdefault(orientation,
                        {'opening_area':0,
                         'surface_area':0,
                         'total_area':0}
                       )
    x['opening_area']+=opening_area
    x['surface_area']+=surface_area
    x['total_area']+=total_area
    
for k,v in result.items():
    result[k]['window_to_wall_ratio']=result[k]['opening_area'] / result[k]['total_area']
    
result = dict(sorted(result.items()))  # sorts the dictionary by key
    
print(result)
# prints "{0.0: {'opening_area': 1054.302770011667, 
#                'surface_area': 39379.89112896028, 
#                'total_area': 40434.19389897194, 
#                'window_to_wall_ratio': 0.026074534159031996}, 
#         0.01: {'opening_area': 0.0, 
#                'surface_area': 18.75935256182059, 
#                'total_area': 18.75935256182059, 
#                'window_to_wall_ratio': 0.0}, 
#         ...
#         }
# Out:
# Error raised for get_area() of Surface aim13507
# Error raised for get_area() of Surface aim63130
# Error raised for get_area() of Surface aim63304
# Error raised for get_area() of Surface aim63597
# Error raised for get_area() of Surface aim64087
# Error raised for get_area() of Surface aim64196
# Error raised for get_area() of Surface aim64265
# Error raised for get_area() of Surface aim64468
# Error raised for get_area() of Surface aim66653
# Error raised for get_area() of Surface aim66697
# Error raised for get_area() of Surface aim66835
# Error raised for get_area() of Surface aim67086
# Error raised for get_area() of Surface aim67132
# Error raised for get_area() of Surface aim67538
# Error raised for get_area() of Surface aim68038
# Error raised for get_area() of Surface aim68130
# Error raised for get_area() of Surface aim72743
# Error raised for get_area() of Surface aim82996
# Error raised for get_area() of Surface aim87784
# Error raised for get_area() of Surface aim92195
# {0.0: {'opening_area': 1054.302770011667, 'surface_area': 39379.89112896028, 'total_area': 40434.19389897194, 'window_to_wall_ratio': 0.026074534159031996}, 0.01: {'opening_area': 0.0, 'surface_area': 18.75935256182059, 'total_area': 18.75935256182059, 'window_to_wall_ratio': 0.0}, 0.05: {'opening_area': 0.0, 'surface_area': 1192.6100072895795, 'total_area': 1192.6100072895795, 'window_to_wall_ratio': 0.0}, 2.66: {'opening_area': 0.0, 'surface_area': 1.3107892790000428, 'total_area': 1.3107892790000428, 'window_to_wall_ratio': 0.0}, 3.01: {'opening_area': 0.0, 'surface_area': 4.987147412000004, 'total_area': 4.987147412000004, 'window_to_wall_ratio': 0.0}, 4.23: {'opening_area': 0.0, 'surface_area': 0.8111042469999654, 'total_area': 0.8111042469999654, 'window_to_wall_ratio': 0.0}, 5.71: {'opening_area': 0.0, 'surface_area': 6.487031195000009, 'total_area': 6.487031195000009, 'window_to_wall_ratio': 0.0}, 11.62: {'opening_area': 0.0, 'surface_area': 6.233515919000058, 'total_area': 6.233515919000058, 'window_to_wall_ratio': 0.0}, 15.94: {'opening_area': 0.0, 'surface_area': 22.716443654999935, 'total_area': 22.716443654999935, 'window_to_wall_ratio': 0.0}, 16.69: {'opening_area': 0.0, 'surface_area': 1.7453452365000057, 'total_area': 1.7453452365000057, 'window_to_wall_ratio': 0.0}, 18.42: {'opening_area': 0.0, 'surface_area': 2.119330825500093, 'total_area': 2.119330825500093, 'window_to_wall_ratio': 0.0}, 22.24: {'opening_area': 0.0, 'surface_area': 508.5041279939017, 'total_area': 508.5041279939017, 'window_to_wall_ratio': 0.0}, 23.48: {'opening_area': 0.0, 'surface_area': 121.04090600708672, 'total_area': 121.04090600708672, 'window_to_wall_ratio': 0.0}, 23.88: {'opening_area': 0.0, 'surface_area': 364.55674842680736, 'total_area': 364.55674842680736, 'window_to_wall_ratio': 0.0}, 23.94: {'opening_area': 0.0, 'surface_area': 1.7453577144999999, 'total_area': 1.7453577144999999, 'window_to_wall_ratio': 0.0}, 26.54: {'opening_area': 0.0, 'surface_area': 0.49866578300001324, 'total_area': 0.49866578300001324, 'window_to_wall_ratio': 0.0}, 27.07: {'opening_area': 0.0, 'surface_area': 700.2144936199999, 'total_area': 700.2144936199999, 'window_to_wall_ratio': 0.0}, 28.28: {'opening_area': 0.0, 'surface_area': 2.618049060999992, 'total_area': 2.618049060999992, 'window_to_wall_ratio': 0.0}, 29.04: {'opening_area': 0.0, 'surface_area': 338.99952104324996, 'total_area': 338.99952104324996, 'window_to_wall_ratio': 0.0}, 30.23: {'opening_area': 0.0, 'surface_area': 2.493338919999985, 'total_area': 2.493338919999985, 'window_to_wall_ratio': 0.0}, 31.98: {'opening_area': 0.0, 'surface_area': 1.7453427409999946, 'total_area': 1.7453427409999946, 'window_to_wall_ratio': 0.0}, 32.8: {'opening_area': 0.0, 'surface_area': 3.3036627069999973, 'total_area': 3.3036627069999973, 'window_to_wall_ratio': 0.0}, 33.67: {'opening_area': 0.0, 'surface_area': 2.805026892999998, 'total_area': 2.805026892999998, 'window_to_wall_ratio': 0.0}, 34.57: {'opening_area': 0.0, 'surface_area': 3.1790249824999997, 'total_area': 3.1790249824999997, 'window_to_wall_ratio': 0.0}, 34.67: {'opening_area': 0.0, 'surface_area': 2.8673594920000003, 'total_area': 2.8673594920000003, 'window_to_wall_ratio': 0.0}, 36.0: {'opening_area': 0.0, 'surface_area': 6.98161573199998, 'total_area': 6.98161573199998, 'window_to_wall_ratio': 0.0}, 36.84: {'opening_area': 0.0, 'surface_area': 0.2493303959999792, 'total_area': 0.2493303959999792, 'window_to_wall_ratio': 0.0}, 37.16: {'opening_area': 0.0, 'surface_area': 3.304049868000007, 'total_area': 3.304049868000007, 'window_to_wall_ratio': 0.0}, 37.85: {'opening_area': 0.0, 'surface_area': 5.859319229999993, 'total_area': 5.859319229999993, 'window_to_wall_ratio': 0.0}, 39.15: {'opening_area': 0.0, 'surface_area': 4.987045014499984, 'total_area': 4.987045014499984, 'window_to_wall_ratio': 0.0}, 39.26: {'opening_area': 0.0, 'surface_area': 4.114343652499996, 'total_area': 4.114343652499996, 'window_to_wall_ratio': 0.0}, 39.59: {'op ...

# %%
print(surface)
print(surface.get_shell())
print(surface.get_holes())
# Out:
# <Surface (id="aim13507")>
# ((242.8581, 140.6136, 490.0), (247.3558, 140.6136, 490.0), (248.3553, 140.6136, 490.0), (248.3553, 136.1179, 490.0), (242.8581, 140.6136, 490.0))
# []
